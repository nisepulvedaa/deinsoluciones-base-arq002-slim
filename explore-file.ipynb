# %%
import pandas as pd
import pyarrow.parquet as pq

# 📌 Ruta del archivo Parquet
parquet_path = "../salida/instrumentos-derivados-filiales.parquet"

# 📥 Leer archivo
df = pd.read_parquet(parquet_path)

# 🔍 Configurar pandas para mostrar todo sin truncar
pd.set_option('display.max_colwidth', None)  # sin límite de ancho
pd.set_option('display.max_columns', None)   # mostrar todas las columnas
pd.set_option('display.expand_frame_repr', False)  # evita corte en filas largas

# 🖨️ Mostrar primeras 5 filas
print("\n🔎 Primeros 5 registros:")
display(df.head(5))

# 📥 Leer el archivo Parquet y extraer esquema
print("📊 Esquema del Parquet:")
table = pq.read_table(parquet_path)
schema = table.schema

# 🧠 Imprimir esquema nativo
print("📜 Esquema desde el archivo Parquet (pyarrow):")
print(schema)
# Out:
# 🔎 Primeros 5 registros:
#   deriva_fec_periodo_cierre deriva_cod_filial deriva_num_rut_deudor deriva_cod_operacion deriva_tip_derivado deriva_fec_inicio deriva_fec_venc deriva_nom_mnd_derecho deriva_cod_mnd_derecho deriva_ctd_derecho_contrato deriva_nom_mnd_obligacion deriva_cod_mnd_obligacion deriva_ctd_obligacion_contra deriva_mon_justo_clp deriva_mon_tc_contrato deriva_mon_tc_valor_justo deriva_pct_factor deriva_num_dias_venc deriva_ind_netting deriva_dsc_tip_tasa_activo deriva_dsc_tip_tasa_pasivo
# 0                2025-04-24               BCB              46146815             SLA1UA1Y            IRS Swap        2025-04-15      2035-04-17                    CLP                      1            10000000000.0000                       CLP                         1             10000000000.0000        -7756892.7922                 1.0000                    1.0000             0.015                  364                 SI                       FIJO                   VARIABLE
# 1                2025-04-24               BCB              46146815               318637          Fx Forward        2025-04-15      2035-04-17                    USD                     11               15513246.8600                       CLP                         1             14671498085.0000     -1425065544.0000               945.7400                  936.2800             0.015                  250                 SI                         NA                         NA
# 2                2025-04-24               BCB              52640121               318638          Fx Forward        2025-04-15      2035-04-17                    CLF                     98                 500000.0000                       CLP                         1             19776000000.0000       252325771.0000             39552.0000                39036.4500                 0                  150                 SI                         NA                         NA
# 3                2025-04-24               BCB              52640121               318639          Fx Forward        2025-04-15      2035-04-17                    CLP                      1             9722019148.0000                       USD                        11                10396213.6000       -12758877.0000               935.1500                  936.2800             0.015                  240                 SI                         NA                         NA
# 4                2025-04-24               BCB              52640121               318640          Fx Forward        2025-04-15      2035-04-17                    CLP                      1             4861058012.0000                       USD                        11                5175963.64000        14328781.0000               935.1600                  936.2800             0.015                  110                 SI                         NA                         NA
# 📊 Esquema del Parquet:
# 📜 Esquema desde el archivo Parquet (pyarrow):
# deriva_fec_periodo_cierre: date32[day]
# deriva_cod_filial: string
# deriva_num_rut_deudor: string
# deriva_cod_operacion: string
# deriva_tip_derivado: string
# deriva_fec_inicio: date32[day]
# deriva_fec_venc: date32[day]
# deriva_nom_mnd_derecho: string
# deriva_cod_mnd_derecho: string
# deriva_ctd_derecho_contrato: string
# deriva_nom_mnd_obligacion: string
# deriva_cod_mnd_obligacion: string
# deriva_ctd_obligacion_contra: string
# deriva_mon_justo_clp: string
# deriva_mon_tc_contrato: string
# deriva_mon_tc_valor_justo: string
# deriva_pct_factor: string
# deriva_num_dias_venc: string
# deriva_ind_netting: string
# deriva_dsc_tip_tasa_activo: string
# deriva_dsc_tip_tasa_pasivo: string
# -- schema metadata --
# pandas: '{"index_columns": [], "column_indexes": [], "columns": [{"name":' + 3080
